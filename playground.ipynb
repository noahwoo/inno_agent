# %%
from langchain.llms import OpenAI
from langchain import PromptTemplate, FewShotPromptTemplate
import os

print(os.environ['HOME'])
print(os.environ['OPENAI_API_KEY'])

llm = OpenAI(model_name="text-davinci-003", n=2, best_of=2)
print(llm("给我讲个笑话？"))

# try a few-shot In-Context Learning setting
examples = [{'word':'好', 'antonym':'坏'}, 
    {'word':'快', 'antonym':'慢'}]

format_template = """
原词: {word}
反义词: {antonym}\n
"""

example_prompt = PromptTemplate(
    input_variables = ['word', 'antonym'],
    template = format_template
)

few_shot_prompt = FewShotPromptTemplate(
    examples = examples, 
    example_prompt = example_prompt,
    prefix = "给出输入的反义词", 
    suffix = "原词: {input}\n反义词:",
    input_variables = ["input"], 
    # the string we join the prefix, examples and suffix
    example_separator = "\n"
)

input = '开心'

print(few_shot_prompt.format(input=input))
print(llm(few_shot_prompt.format(input=input)))
# Out:
# /Users/wujianmin
# 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
#
#
# 两个熊在谈论他们最喜欢的电影。第一只熊说：“我最喜欢《熊出没》！”第二只熊说：“我最喜欢《熊不出没》！”
# 给出输入的反义词
#
# 原词: 好
# 反义词: 坏
#
#
#
# 原词: 快
# 反义词: 慢
#
#
# 原词: 开心
# 反义词:
#  不开心

# %%
from typing import List, Dict

def prompt_one_author(authid : str, examples : List[Dict[str, str]], few_shot_ratio = 0.8, min_reply = 4) :

    example_num = len(examples)
    if example_num < min_reply :
        print("Minimum reply required {0}, received {1} for author {2}".format(min_reply, example_num, authid))
        return
    
    # llm to use
    llm = OpenAI(model_name="text-davinci-003", n=2, best_of=2)
    # Few-shot learning template
    format_template = """
    评论：{post}
    回复：{reply}\n
    """
    
    few_shot_num = int(example_num * few_shot_ratio)
    print(examples[:few_shot_num])

    example_prompt = PromptTemplate(
        input_variables = ['post', 'reply'],
        template = format_template
    )
    
    few_shot_prompt = FewShotPromptTemplate(
        examples = examples[:few_shot_num], 
        example_prompt = example_prompt,
        prefix = "作为一个创作者，请给用户的评论做出回复", 
        suffix = "评论：{input}\n回复：",
        input_variables = ["input"], 
        example_separator = "\n"
    )

    print(few_shot_prompt.format(input="A"))

    for example in examples[few_shot_num:] :
        print("LLM reply: {0}, Author reply: {1}".format(
            llm(few_shot_prompt.format(input=example['post'])), example['reply']))

# %%
import sys
import json

def extract_author_reply(input_stream) :
    # read video comments line by line

    authid_prev = None
    auth_reply_buffer = []

    for line in input_stream:
        video_comments = json.loads(line)
        title = video_comments['title']
        authid = video_comments['mthid']
        for comment in video_comments['comment'] :
            content = comment['comment_content']
            if 'reply_list' in comment :
                for reply in comment['reply_list'] :
                    if reply['is_author'] == '1' :
                        # print("{0}\t#{1}\t#{2}\t#{3}".format(authid, title, content, reply['content']))
                        auth_reply_buffer.append({"post":content, "reply":reply["content"]})
        if authid_prev != None and authid != authid_prev : 
            print("===Reply generation for author {0}===\n".format(authid_prev))
            prompt_one_author(authid_prev, auth_reply_buffer)
            auth_reply_buffer = []

        authid_prev = authid

# %%
file_path = '/Users/wujianmin/bak-from-mac/PycharmProjects/work-notes/code/comment_info_20w.json'
with open(file_path) as fin :
    extract_author_reply(fin)
# Out:
# ===Reply generation for author 1710771319626650===
#
# Minimum reply required 4, received 0 for author 1710771319626650
# ===Reply generation for author 1560184445643243===
#
# Minimum reply required 4, received 0 for author 1560184445643243
# ===Reply generation for author 1753607923150347===
#
# Minimum reply required 4, received 0 for author 1753607923150347
# ===Reply generation for author 1655533672430779===
#
# Minimum reply required 4, received 1 for author 1655533672430779
# ===Reply generation for author 1629593136560128===
#
# [{'post': '真是能忽悠人，经营药店看地段看人，是三两句能说清楚的', 'reply': '我怎么忽悠人了，我说的是不是事实，我又没让你们给我钱，我也没要求你付费，怎么就忽悠人了，喜欢看就看，不喜欢看就略过'}, {'post': '医院2块6毛的阿莫西林，药房卖26，你说赚钱不赚钱！', 'reply': '主要是医院有些药不卖给你。美林医院10来块钱，外面最高的时候炒到2500，还买不到'}, {'post': '开的试试看，起码不赔钱吧', 'reply': '这个不一定'}, {'post': '我也想开，正看房子', 'reply': '尽量不要选择竞争激烈的地方，选择入住量大的小区，尽量选择方便停车，方便走过路人的地方'}, {'post': '看你开什么样的,一般来说还是比较赚钱的,但要有好的经营理念', 'reply': '很对'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：真是能忽悠人，经营药店看地段看人，是三两句能说清楚的
#     回复：我怎么忽悠人了，我说的是不是事实，我又没让你们给我钱，我也没要求你付费，怎么就忽悠人了，喜欢看就看，不喜欢看就略过
#
#
#
#     评论：医院2块6毛的阿莫西林，药房卖26，你说赚钱不赚钱！
#     回复：主要是医院有些药不卖给你。美林医院10来块钱，外面最高的时候炒到2500，还买不到
#
#
#
#     评论：开的试试看，起码不赔钱吧
#     回复：这个不一定
#
#
#
#     评论：我也想开，正看房子
#     回复：尽量不要选择竞争激烈的地方，选择入住量大的小区，尽量选择方便停车，方便走过路人的地方
#
#
#
#     评论：看你开什么样的,一般来说还是比较赚钱的,但要有好的经营理念
#     回复：很对
#
#
# 评论：A
# 回复：
# LLM reply: 这个取决于你的经营理念，要有良好的服务意识，为顾客提供满意的服务，这样才能赚到钱。, Author reply: 对，在难干的生意也有干的风生水起的
# LLM reply: 如果你有充分的准备，有足够的市场调研、对客户需求的了解和一定的资金支撑，想自己开一家药店是可行的。, Author reply: 富二代可以，白手起家就算了，竞争太激烈
# ===Reply generation for author 1745951960910369===
#
# Minimum reply required 4, received 0 for author 1745951960910369
# ===Reply generation for author 1563131184918956===
#
# Minimum reply required 4, received 1 for author 1563131184918956
# ===Reply generation for author 1675418192531554===
#
# Minimum reply required 4, received 0 for author 1675418192531554
# ===Reply generation for author 1664760217721609===
#
# Minimum reply required 4, received 0 for author 1664760217721609
# ===Reply generation for author 1703140089291756===
#
# Minimum reply required 4, received 0 for author 1703140089291756
# ===Reply generation for author 1754147536809429===
#
# Minimum reply required 4, received 0 for author 1754147536809429
# ===Reply generation for author 1698265721604506===
#
# Minimum reply required 4, received 0 for author 1698265721604506
# ===Reply generation for author 1549148777647560===
#
# Minimum reply required 4, received 0 for author 1549148777647560
# ===Reply generation for author 1633765546719433===
#
# Minimum reply required 4, received 0 for author 1633765546719433
# ===Reply generation for author 1591009661497809===
#
# Minimum reply required 4, received 0 for author 1591009661497809
# ===Reply generation for author 1537728926913292===
#
# Minimum reply required 4, received 0 for author 1537728926913292
# ===Reply generation for author 1551599273641720===
#
# Minimum reply required 4, received 0 for author 1551599273641720
# ===Reply generation for author 1598221789989706===
#
# Minimum reply required 4, received 0 for author 1598221789989706
# ===Reply generation for author 1561192736257973===
#
# Minimum reply required 4, received 0 for author 1561192736257973
# ===Reply generation for author 1633040335190651===
#
# Minimum reply required 4, received 0 for author 1633040335190651
# ===Reply generation for author 1686484186581841===
#
# Minimum reply required 4, received 0 for author 1686484186581841
# ===Reply generation for author 1672563761251728===
#
# Minimum reply required 4, received 0 for author 1672563761251728
# ===Reply generation for author 1537272048555583===
#
# Minimum reply required 4, received 0 for author 1537272048555583
# ===Reply generation for author 1672900678421624===
#
# Minimum reply required 4, received 0 for author 1672900678421624
# ===Reply generation for author 1754893970362787===
#
# Minimum reply required 4, received 0 for author 1754893970362787
# ===Reply generation for author 1741468301990158===
#
# Minimum reply required 4, received 0 for author 1741468301990158
# ===Reply generation for author 1552886042539767===
#
# Minimum reply required 4, received 0 for author 1552886042539767
# ===Reply generation for author 1730522575078275===
#
# Minimum reply required 4, received 0 for author 1730522575078275
# ===Reply generation for author 1752157944614964===
#
# Minimum reply required 4, received 0 for author 1752157944614964
# ===Reply generation for author 1653054989011985===
#
# Minimum reply required 4, received 0 for author 1653054989011985
# ===Reply generation for author 1586552342649105===
#
# Minimum reply required 4, received 0 for author 1586552342649105
# ===Reply generation for author 1612402749011336===
#
# Minimum reply required 4, received 0 for author 1612402749011336
# ===Reply generation for author 1728606716756275===
#
# Minimum reply required 4, received 0 for author 1728606716756275
# ===Reply generation for author 1598514624320041===
#
# Minimum reply required 4, received 0 for author 1598514624320041
# ===Reply generation for author 1634381284280718===
#
# Minimum reply required 4, received 0 for author 1634381284280718
# ===Reply generation for author 1537750576583647===
#
# Minimum reply required 4, received 0 for author 1537750576583647
# ===Reply generation for author 1718267628818109===
#
# Minimum reply required 4, received 3 for author 1718267628818109
# ===Reply generation for author 1750084049778654===
#
# Minimum reply required 4, received 0 for author 1750084049778654
# ===Reply generation for author 1754895081195475===
#
# Minimum reply required 4, received 0 for author 1754895081195475
# ===Reply generation for author 1593340312448951===
#
# Minimum reply required 4, received 3 for author 1593340312448951
# ===Reply generation for author 1739191937917029===
#
# Minimum reply required 4, received 0 for author 1739191937917029
# ===Reply generation for author 1665949971318424===
#
# Minimum reply required 4, received 0 for author 1665949971318424
# ===Reply generation for author 1611927141597564===
#
# Minimum reply required 4, received 0 for author 1611927141597564
# ===Reply generation for author 1563006460027134===
#
# Minimum reply required 4, received 0 for author 1563006460027134
# ===Reply generation for author 1565092142508658===
#
# Minimum reply required 4, received 0 for author 1565092142508658
# ===Reply generation for author 1610024681846801===
#
# Minimum reply required 4, received 0 for author 1610024681846801
# ===Reply generation for author 1549608413453462===
#
# Minimum reply required 4, received 0 for author 1549608413453462
# ===Reply generation for author 1733757146468545===
#
# Minimum reply required 4, received 0 for author 1733757146468545
# ===Reply generation for author 1682983600213463===
#
# Minimum reply required 4, received 0 for author 1682983600213463
# ===Reply generation for author 1549761396709004===
#
# Minimum reply required 4, received 0 for author 1549761396709004
# ===Reply generation for author 1565176801499628===
#
# [{'post': '你可以把他引来', 'reply': '谢谢你的评论'}, {'post': '老巩去山东不比你北控强多了北控还继续张劲松带队就行…', 'reply': '谢谢你的评论'}, {'post': '来高速吧', 'reply': '谢谢你的评论'}, {'post': '你说啥有用吗？', 'reply': '谢谢你的评论'}, {'post': '瞪俩眼睛说瞎话，接触沃克的是北京队！辽宁队缺后卫吗？', 'reply': '谢谢你的评论'}, {'post': '真正欠佳的是赵继伟而非胡明轩和徐杰！', 'reply': '谢谢你的评论'}, {'post': '赵继伟打不了关键比赛，以后不能带他进国家队了', 'reply': '谢谢你的评论'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：你可以把他引来
#     回复：谢谢你的评论
#
#
#
#     评论：老巩去山东不比你北控强多了北控还继续张劲松带队就行…
#     回复：谢谢你的评论
#
#
#
#     评论：来高速吧
#     回复：谢谢你的评论
#
#
#
#     评论：你说啥有用吗？
#     回复：谢谢你的评论
#
#
#
#     评论：瞪俩眼睛说瞎话，接触沃克的是北京队！辽宁队缺后卫吗？
#     回复：谢谢你的评论
#
#
#
#     评论：真正欠佳的是赵继伟而非胡明轩和徐杰！
#     回复：谢谢你的评论
#
#
#
#     评论：赵继伟打不了关键比赛，以后不能带他进国家队了
#     回复：谢谢你的评论
#
#
# 评论：A
# 回复：
# LLM reply: 谢谢你的评论。, Author reply: 谢谢你的评论
# LLM reply: 谢谢你的评论。, Author reply: 谢谢你的评论
# ===Reply generation for author 1700911689346452===
#
# Minimum reply required 4, received 0 for author 1700911689346452
# ===Reply generation for author 1596929623277689===
#
# Minimum reply required 4, received 0 for author 1596929623277689
# ===Reply generation for author 1671361504545612===
#
# Minimum reply required 4, received 0 for author 1671361504545612
# ===Reply generation for author 1676014563218865===
#
# Minimum reply required 4, received 0 for author 1676014563218865
# ===Reply generation for author 1754153826362242===
#
# Minimum reply required 4, received 0 for author 1754153826362242
# ===Reply generation for author 1577232526219744===
#
# Minimum reply required 4, received 2 for author 1577232526219744
# ===Reply generation for author 1754160030837921===
#
# Minimum reply required 4, received 0 for author 1754160030837921
# ===Reply generation for author 1704963405605672===
#
# Minimum reply required 4, received 0 for author 1704963405605672
# ===Reply generation for author 1550971979907812===
#
# Minimum reply required 4, received 0 for author 1550971979907812
# ===Reply generation for author 1756607958702905===
#
# Minimum reply required 4, received 0 for author 1756607958702905
# ===Reply generation for author 1716467664275144===
#
# Minimum reply required 4, received 0 for author 1716467664275144
# ===Reply generation for author 1612843692099912===
#
# Minimum reply required 4, received 0 for author 1612843692099912
# ===Reply generation for author 1683226446645151===
#
# Minimum reply required 4, received 0 for author 1683226446645151
# ===Reply generation for author 1724341216729562===
#
# Minimum reply required 4, received 1 for author 1724341216729562
# ===Reply generation for author 1751989598179220===
#
# Minimum reply required 4, received 0 for author 1751989598179220
# ===Reply generation for author 1537340396388629===
#
# Minimum reply required 4, received 0 for author 1537340396388629
# ===Reply generation for author 1601669912838773===
#
# Minimum reply required 4, received 0 for author 1601669912838773
# ===Reply generation for author 1630481416088435===
#
# Minimum reply required 4, received 0 for author 1630481416088435
# ===Reply generation for author 1662207396778759===
#
# Minimum reply required 4, received 0 for author 1662207396778759
# ===Reply generation for author 24394===
#
# Minimum reply required 4, received 0 for author 24394
# ===Reply generation for author 1598318062761846===
#
# Minimum reply required 4, received 0 for author 1598318062761846
# ===Reply generation for author 1579408086880300===
#
# Minimum reply required 4, received 0 for author 1579408086880300
# ===Reply generation for author 1616837609956250===
#
# Minimum reply required 4, received 0 for author 1616837609956250
# ===Reply generation for author 1593562955141943===
#
# Minimum reply required 4, received 0 for author 1593562955141943
# ===Reply generation for author 1549761396709004===
#
# Minimum reply required 4, received 0 for author 1549761396709004
# ===Reply generation for author 1667653178835422===
#
# Minimum reply required 4, received 0 for author 1667653178835422
# ===Reply generation for author 1551592787799016===
#
# Minimum reply required 4, received 0 for author 1551592787799016
# ===Reply generation for author 1601876399268450===
#
# Minimum reply required 4, received 0 for author 1601876399268450
# ===Reply generation for author 1536766194521709===
#
# Minimum reply required 4, received 0 for author 1536766194521709
# ===Reply generation for author 1549608413453462===
#
# Minimum reply required 4, received 0 for author 1549608413453462
# ===Reply generation for author 1747651136027550===
#
# Minimum reply required 4, received 0 for author 1747651136027550
# ===Reply generation for author 1744087203009489===
#
# Minimum reply required 4, received 0 for author 1744087203009489
# ===Reply generation for author 1627516726837239===
#
# Minimum reply required 4, received 0 for author 1627516726837239
# ===Reply generation for author 1561836238427420===
#
# Minimum reply required 4, received 2 for author 1561836238427420
# ===Reply generation for author 1706208150298544===
#
# Minimum reply required 4, received 0 for author 1706208150298544
# ===Reply generation for author 1704819294744993===
#
# Minimum reply required 4, received 3 for author 1704819294744993
# ===Reply generation for author 1754895712538220===
#
# Minimum reply required 4, received 0 for author 1754895712538220
# ===Reply generation for author 1734759508638645===
#
# Minimum reply required 4, received 0 for author 1734759508638645
# ===Reply generation for author 1551869517442410===
#
# Minimum reply required 4, received 0 for author 1551869517442410
# ===Reply generation for author 1684344483929461===
#
# Minimum reply required 4, received 0 for author 1684344483929461
# ===Reply generation for author 1537196318595058===
#
# Minimum reply required 4, received 0 for author 1537196318595058
# ===Reply generation for author 1566365578755720===
#
# Minimum reply required 4, received 0 for author 1566365578755720
# ===Reply generation for author 1536771024577398===
#
# Minimum reply required 4, received 0 for author 1536771024577398
# ===Reply generation for author 1661923424856389===
#
# Minimum reply required 4, received 1 for author 1661923424856389
# ===Reply generation for author 1752792469950190===
#
# Minimum reply required 4, received 0 for author 1752792469950190
# ===Reply generation for author 1598252816057128===
#
# Minimum reply required 4, received 0 for author 1598252816057128
# ===Reply generation for author 1623263254161077===
#
# Minimum reply required 4, received 0 for author 1623263254161077
# ===Reply generation for author 1573870491330861===
#
# Minimum reply required 4, received 0 for author 1573870491330861
# ===Reply generation for author 1582470689476582===
#
# Minimum reply required 4, received 0 for author 1582470689476582
# ===Reply generation for author 1587267721576374===
#
# Minimum reply required 4, received 0 for author 1587267721576374
# ===Reply generation for author 1653591314924110===
#
# Minimum reply required 4, received 0 for author 1653591314924110
# ===Reply generation for author 1702832799527633===
#
# Minimum reply required 4, received 0 for author 1702832799527633
# ===Reply generation for author 1724729261374652===
#
# Minimum reply required 4, received 0 for author 1724729261374652
# ===Reply generation for author 1695751122455364===
#
# Minimum reply required 4, received 0 for author 1695751122455364
# ===Reply generation for author 1566365578755720===
#
# Minimum reply required 4, received 0 for author 1566365578755720
# ===Reply generation for author 1713963699529756===
#
# Minimum reply required 4, received 0 for author 1713963699529756
# ===Reply generation for author 1744114630347548===
#
# Minimum reply required 4, received 1 for author 1744114630347548
# ===Reply generation for author 1756236885315810===
#
# Minimum reply required 4, received 0 for author 1756236885315810
# ===Reply generation for author 1744369460163656===
#
# Minimum reply required 4, received 0 for author 1744369460163656
# ===Reply generation for author 1536770775191680===
#
# Minimum reply required 4, received 0 for author 1536770775191680
# ===Reply generation for author 1593527168637823===
#
# Minimum reply required 4, received 0 for author 1593527168637823
# ===Reply generation for author 1552507899985619===
#
# Minimum reply required 4, received 0 for author 1552507899985619
# ===Reply generation for author 1546608532556400===
#
# Minimum reply required 4, received 0 for author 1546608532556400
# ===Reply generation for author 1577331609698508===
#
# Minimum reply required 4, received 0 for author 1577331609698508
# ===Reply generation for author 1572542821499569===
#
# Minimum reply required 4, received 0 for author 1572542821499569
# ===Reply generation for author 1621699794843978===
#
# Minimum reply required 4, received 2 for author 1621699794843978
# ===Reply generation for author 1753961128819507===
#
# Minimum reply required 4, received 0 for author 1753961128819507
# ===Reply generation for author 1627434193695300===
#
# Minimum reply required 4, received 0 for author 1627434193695300
# ===Reply generation for author 1750090630585668===
#
# Minimum reply required 4, received 1 for author 1750090630585668
# ===Reply generation for author 1753020025382408===
#
# Minimum reply required 4, received 0 for author 1753020025382408
# ===Reply generation for author 1644011241267702===
#
# Minimum reply required 4, received 0 for author 1644011241267702
# ===Reply generation for author 1568979149392039===
#
# Minimum reply required 4, received 0 for author 1568979149392039
# ===Reply generation for author 1608858068443684===
#
# Minimum reply required 4, received 0 for author 1608858068443684
# ===Reply generation for author 1741108350479491===
#
# Minimum reply required 4, received 0 for author 1741108350479491
# ===Reply generation for author 1569624596690223===
#
# Minimum reply required 4, received 0 for author 1569624596690223
# ===Reply generation for author 1590909251197005===
#
# Minimum reply required 4, received 0 for author 1590909251197005
# ===Reply generation for author 1601769692556620===
#
# Minimum reply required 4, received 0 for author 1601769692556620
# ===Reply generation for author 1680604191501278===
#
# Minimum reply required 4, received 0 for author 1680604191501278
# ===Reply generation for author 1743369248901340===
#
# Minimum reply required 4, received 1 for author 1743369248901340
# ===Reply generation for author 1743112968057016===
#
# Minimum reply required 4, received 0 for author 1743112968057016
# ===Reply generation for author 1549608413453462===
#
# Minimum reply required 4, received 0 for author 1549608413453462
# ===Reply generation for author 1567560395730380===
#
# Minimum reply required 4, received 0 for author 1567560395730380
# ===Reply generation for author 1712643209716303===
#
# Minimum reply required 4, received 1 for author 1712643209716303
# ===Reply generation for author 1741303455118482===
#
# Minimum reply required 4, received 0 for author 1741303455118482
# ===Reply generation for author 1611486544265158===
#
# Minimum reply required 4, received 0 for author 1611486544265158
# ===Reply generation for author 1537196318595058===
#
# Minimum reply required 4, received 0 for author 1537196318595058
# ===Reply generation for author 1591183126818966===
#
# Minimum reply required 4, received 0 for author 1591183126818966
# ===Reply generation for author 1553228274475305===
#
# Minimum reply required 4, received 0 for author 1553228274475305
# ===Reply generation for author 1572792144066571===
#
# Minimum reply required 4, received 0 for author 1572792144066571
# ===Reply generation for author 1715664717997569===
#
# Minimum reply required 4, received 1 for author 1715664717997569
# ===Reply generation for author 1562575519594075===
#
# Minimum reply required 4, received 0 for author 1562575519594075
# ===Reply generation for author 1555432398439423===
#
# Minimum reply required 4, received 0 for author 1555432398439423
# ===Reply generation for author 1740500496091498===
#
# Minimum reply required 4, received 0 for author 1740500496091498
# ===Reply generation for author 1570547692394543===
#
# Minimum reply required 4, received 0 for author 1570547692394543
# ===Reply generation for author 1728982710366763===
#
# Minimum reply required 4, received 0 for author 1728982710366763
# ===Reply generation for author 1606746419315368===
#
# Minimum reply required 4, received 0 for author 1606746419315368
# ===Reply generation for author 1537272048555583===
#
# Minimum reply required 4, received 0 for author 1537272048555583
# ===Reply generation for author 1581417569484213===
#
# Minimum reply required 4, received 0 for author 1581417569484213
# ===Reply generation for author 1575336929000910===
#
# Minimum reply required 4, received 0 for author 1575336929000910
# ===Reply generation for author 1573162320060777===
#
# Minimum reply required 4, received 0 for author 1573162320060777
# ===Reply generation for author 1562213386656692===
#
# Minimum reply required 4, received 0 for author 1562213386656692
# ===Reply generation for author 1693907845226356===
#
# [{'post': '不完整的家庭，会造就出“问题孩子”，影响未来的花朵，这一点作为老师体会最深', 'reply': '是很有责任心的老师，的确会有这么方面的问题存在[赞同]'}, {'post': '唉，以后男人们有了孩子记得做亲子鉴定，不是自己的就不用抚养了', 'reply': '男人可以抚养自己的孩子'}, {'post': '又多出许多不知道爸爸是谁的孩子，以后孩子出了问题，又说是家庭问题，爸爸缺失[左捂脸][左捂脸][左捂脸]造成的孩子心理问题', 'reply': '选择面更宽泛啦，可以选择生，也可以选择不生'}, {'post': '我们要作智慧人！人品！三人合成一台戏！我们装的是灵！魂！体！♥心灵相通！心情愉悦舒畅！灵性美好！心中充满阳光！爱得滋润！温柔体贴[微笑]善良的人！善要贴近！远离恶事！有良知！明白事理！走向光明[衰]活在善恶之中！善恶不分家！活在肉体中充满恶！有谎言的魔力！使许多人受到无形的伤害！这话都要闷心自问！我是谁！这是人所结的果子！从前没有结婚证！又结婚！又生儿！不离婚！离婚是羞耻！有了结婚证！又有婚姻法！离婚高！法律不能约束人！良心才能管理！', 'reply': '是滴[赞同]'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：不完整的家庭，会造就出“问题孩子”，影响未来的花朵，这一点作为老师体会最深
#     回复：是很有责任心的老师，的确会有这么方面的问题存在[赞同]
#
#
#
#     评论：唉，以后男人们有了孩子记得做亲子鉴定，不是自己的就不用抚养了
#     回复：男人可以抚养自己的孩子
#
#
#
#     评论：又多出许多不知道爸爸是谁的孩子，以后孩子出了问题，又说是家庭问题，爸爸缺失[左捂脸][左捂脸][左捂脸]造成的孩子心理问题
#     回复：选择面更宽泛啦，可以选择生，也可以选择不生
#
#
#
#     评论：我们要作智慧人！人品！三人合成一台戏！我们装的是灵！魂！体！♥心灵相通！心情愉悦舒畅！灵性美好！心中充满阳光！爱得滋润！温柔体贴[微笑]善良的人！善要贴近！远离恶事！有良知！明白事理！走向光明[衰]活在善恶之中！善恶不分家！活在肉体中充满恶！有谎言的魔力！使许多人受到无形的伤害！这话都要闷心自问！我是谁！这是人所结的果子！从前没有结婚证！又结婚！又生儿！不离婚！离婚是羞耻！有了结婚证！又有婚姻法！离婚高！法律不能约束人！良心才能管理！
#     回复：是滴[赞同]
#
#
# 评论：A
# 回复：
# LLM reply: 深刻的观点[赞同]，法律是有限的，只有良心和责任感更能牢牢把握婚姻家庭，让孩子们更加幸福。, Author reply: 对哒，事物的诞生是有生命周期的，这可能是个必然的阶段
# ===Reply generation for author 1701693397069808===
#
# Minimum reply required 4, received 0 for author 1701693397069808
# ===Reply generation for author 1754236050748307===
#
# Minimum reply required 4, received 1 for author 1754236050748307
# ===Reply generation for author 1726272389338572===
#
# Minimum reply required 4, received 0 for author 1726272389338572
# ===Reply generation for author 1549679538283160===
#
# Minimum reply required 4, received 0 for author 1549679538283160
# ===Reply generation for author 1595280607485927===
#
# Minimum reply required 4, received 0 for author 1595280607485927
# ===Reply generation for author 1589184613062459===
#
# Minimum reply required 4, received 0 for author 1589184613062459
# ===Reply generation for author 1639175826179665===
#
# Minimum reply required 4, received 0 for author 1639175826179665
# ===Reply generation for author 1748353150202335===
#
# Minimum reply required 4, received 0 for author 1748353150202335
# ===Reply generation for author 1673719731538209===
#
# Minimum reply required 4, received 0 for author 1673719731538209
# ===Reply generation for author 1586369203928687===
#
# Minimum reply required 4, received 0 for author 1586369203928687
# ===Reply generation for author 1754904914593761===
#
# Minimum reply required 4, received 0 for author 1754904914593761
# ===Reply generation for author 1603486882393490===
#
# Minimum reply required 4, received 0 for author 1603486882393490
# ===Reply generation for author 1662681725473514===
#
# Minimum reply required 4, received 0 for author 1662681725473514
# ===Reply generation for author 1572584924988892===
#
# Minimum reply required 4, received 0 for author 1572584924988892
# ===Reply generation for author 1630388120529444===
#
# Minimum reply required 4, received 1 for author 1630388120529444
# ===Reply generation for author 1732582557286643===
#
# Minimum reply required 4, received 3 for author 1732582557286643
# ===Reply generation for author 1733667074699348===
#
# Minimum reply required 4, received 0 for author 1733667074699348
# ===Reply generation for author 1561825967470087===
#
# Minimum reply required 4, received 0 for author 1561825967470087
# ===Reply generation for author 1696979093982396===
#
# Minimum reply required 4, received 0 for author 1696979093982396
# ===Reply generation for author 1619808788120960===
#
# Minimum reply required 4, received 0 for author 1619808788120960
# ===Reply generation for author 1551777297442855===
#
# Minimum reply required 4, received 0 for author 1551777297442855
# ===Reply generation for author 1697069350793528===
#
# Minimum reply required 4, received 0 for author 1697069350793528
# ===Reply generation for author 1700349404136413===
#
# Minimum reply required 4, received 0 for author 1700349404136413
# ===Reply generation for author 1634423075878912===
#
# Minimum reply required 4, received 0 for author 1634423075878912
# ===Reply generation for author 1537281685766988===
#
# Minimum reply required 4, received 0 for author 1537281685766988
# ===Reply generation for author 1577676963562678===
#
# Minimum reply required 4, received 0 for author 1577676963562678
# ===Reply generation for author 1715028281743093===
#
# Minimum reply required 4, received 1 for author 1715028281743093
# ===Reply generation for author 1651432290525245===
#
# Minimum reply required 4, received 0 for author 1651432290525245
# ===Reply generation for author 1754154137851677===
#
# Minimum reply required 4, received 0 for author 1754154137851677
# ===Reply generation for author 1664044695272215===
#
# Minimum reply required 4, received 0 for author 1664044695272215
# ===Reply generation for author 1656005066968079===
#
# Minimum reply required 4, received 0 for author 1656005066968079
# ===Reply generation for author 1536770241420293===
#
# Minimum reply required 4, received 0 for author 1536770241420293
# ===Reply generation for author 1611960798822061===
#
# Minimum reply required 4, received 0 for author 1611960798822061
# ===Reply generation for author 1549608413453462===
#
# Minimum reply required 4, received 0 for author 1549608413453462
# ===Reply generation for author 1670745022109384===
#
# Minimum reply required 4, received 0 for author 1670745022109384
# ===Reply generation for author 1682945396532510===
#
# Minimum reply required 4, received 0 for author 1682945396532510
# ===Reply generation for author 1567722747493693===
#
# Minimum reply required 4, received 0 for author 1567722747493693
# ===Reply generation for author 1575893350646054===
#
# Minimum reply required 4, received 0 for author 1575893350646054
# ===Reply generation for author 1691655152095718===
#
# Minimum reply required 4, received 0 for author 1691655152095718
# ===Reply generation for author 1631145223522169===
#
# Minimum reply required 4, received 0 for author 1631145223522169
# ===Reply generation for author 1694744007512750===
#
# Minimum reply required 4, received 1 for author 1694744007512750
# ===Reply generation for author 1751301042735648===
#
# Minimum reply required 4, received 0 for author 1751301042735648
# ===Reply generation for author 1707760895038024===
#
# Minimum reply required 4, received 0 for author 1707760895038024
# ===Reply generation for author 1624881837163345===
#
# Minimum reply required 4, received 2 for author 1624881837163345
# ===Reply generation for author 1672162395407429===
#
# Minimum reply required 4, received 0 for author 1672162395407429
# ===Reply generation for author 1573162320060777===
#
# Minimum reply required 4, received 0 for author 1573162320060777
# ===Reply generation for author 1713963699529756===
#
# Minimum reply required 4, received 1 for author 1713963699529756
# ===Reply generation for author 1741468301990158===
#
# Minimum reply required 4, received 0 for author 1741468301990158
# ===Reply generation for author 1621960424885094===
#
# Minimum reply required 4, received 0 for author 1621960424885094
# ===Reply generation for author 1579064242936995===
#
# Minimum reply required 4, received 0 for author 1579064242936995
# ===Reply generation for author 1635396860449940===
#
# Minimum reply required 4, received 0 for author 1635396860449940
# ===Reply generation for author 1568979149392039===
#
# Minimum reply required 4, received 2 for author 1568979149392039
# ===Reply generation for author 1671250806665199===
#
# Minimum reply required 4, received 1 for author 1671250806665199
# ===Reply generation for author 1702420181243286===
#
# Minimum reply required 4, received 0 for author 1702420181243286
# ===Reply generation for author 1565744158831879===
#
# Minimum reply required 4, received 2 for author 1565744158831879
# ===Reply generation for author 1625166114008622===
#
# [{'post': '诗词大会开始几期，选手是因为对诗词的爱好，进而善长，所以理解的出深，所谓兴趣是最好的老师，，而现在的选手，是因为要出成绩而拼命学习，虽然也背了很多诗词，但其理解程度就差了些，与社会上人们学习考证类似，把在这里好好表现当作成功手段了', 'reply': '有道理'}, {'post': '别人不行你行你上[嘻嘻]服了，就是背古诗你背个我看看[弱]', 'reply': '对别人写的持不同意见你自己写嘛，为什么要背诗给你看？'}, {'post': '小编好像是“诗剩”[弱][弱][弱]', 'reply': '你是诗仙，行了吧[捂脸][捂脸][捂脸]'}, {'post': '不想看就不看，无用话不必说。', 'reply': '咋的，央视节目不允许吐槽吗？'}, {'post': '请问红杜鹃侃娱乐，康震老师做的画画 点评 讲解你行吗？我看你是不行故而才挑毛病的！只赞成你的两点，即加油的场面混乱和千人团出题答题环节存在的问题！', 'reply': '你觉得康老师好你自己替他写一篇嘛[嘻嘻]'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：诗词大会开始几期，选手是因为对诗词的爱好，进而善长，所以理解的出深，所谓兴趣是最好的老师，，而现在的选手，是因为要出成绩而拼命学习，虽然也背了很多诗词，但其理解程度就差了些，与社会上人们学习考证类似，把在这里好好表现当作成功手段了
#     回复：有道理
#
#
#
#     评论：别人不行你行你上[嘻嘻]服了，就是背古诗你背个我看看[弱]
#     回复：对别人写的持不同意见你自己写嘛，为什么要背诗给你看？
#
#
#
#     评论：小编好像是“诗剩”[弱][弱][弱]
#     回复：你是诗仙，行了吧[捂脸][捂脸][捂脸]
#
#
#
#     评论：不想看就不看，无用话不必说。
#     回复：咋的，央视节目不允许吐槽吗？
#
#
#
#     评论：请问红杜鹃侃娱乐，康震老师做的画画 点评 讲解你行吗？我看你是不行故而才挑毛病的！只赞成你的两点，即加油的场面混乱和千人团出题答题环节存在的问题！
#     回复：你觉得康老师好你自己替他写一篇嘛[嘻嘻]
#
#
# 评论：A
# 回复：
# LLM reply: 感谢你的肯定！我会继续努力的！, Author reply: 哟！这指桑骂槐的能力了得[赞同]
# LLM reply: 没错，这两个环节都需要进行改进，才能更好地考核参赛选手的能力。, Author reply: 用“脱颖而出”如何？
# ===Reply generation for author 1565454557117093===
#
# Minimum reply required 4, received 0 for author 1565454557117093
# ===Reply generation for author 1601876399268450===
#
# Minimum reply required 4, received 0 for author 1601876399268450
# ===Reply generation for author 1563462235469851===
#
# Minimum reply required 4, received 0 for author 1563462235469851
# ===Reply generation for author 1536771380218053===
#
# Minimum reply required 4, received 0 for author 1536771380218053
# ===Reply generation for author 1746191915432939===
#
# Minimum reply required 4, received 0 for author 1746191915432939
# ===Reply generation for author 1676236726650068===
#
# Minimum reply required 4, received 0 for author 1676236726650068
# ===Reply generation for author 1756068443485321===
#
# Minimum reply required 4, received 0 for author 1756068443485321
# ===Reply generation for author 1629065868448347===
#
# Minimum reply required 4, received 1 for author 1629065868448347
# ===Reply generation for author 1613631911474058===
#
# Minimum reply required 4, received 0 for author 1613631911474058
# ===Reply generation for author 1586019017887590===
#
# Minimum reply required 4, received 0 for author 1586019017887590
# ===Reply generation for author 1574072008111128===
#
# Minimum reply required 4, received 0 for author 1574072008111128
# ===Reply generation for author 1680437714244435===
#
# Minimum reply required 4, received 0 for author 1680437714244435
# ===Reply generation for author 1647356698373891===
#
# Minimum reply required 4, received 0 for author 1647356698373891
# ===Reply generation for author 1702345914970200===
#
# Minimum reply required 4, received 0 for author 1702345914970200
# ===Reply generation for author 1674373892299193===
#
# Minimum reply required 4, received 2 for author 1674373892299193
# ===Reply generation for author 1546146887776576===
#
# Minimum reply required 4, received 0 for author 1546146887776576
# ===Reply generation for author 1755976373585504===
#
# Minimum reply required 4, received 0 for author 1755976373585504
# ===Reply generation for author 1573162320060777===
#
# Minimum reply required 4, received 0 for author 1573162320060777
# ===Reply generation for author 1754236050748307===
#
# Minimum reply required 4, received 0 for author 1754236050748307
# ===Reply generation for author 1549962689990494===
#
# Minimum reply required 4, received 0 for author 1549962689990494
# ===Reply generation for author 1598962940003039===
#
# Minimum reply required 4, received 0 for author 1598962940003039
# ===Reply generation for author 1566248435989082===
#
# [{'post': '我也在看,我觉得还不错', 'reply': '是的呢'}, {'post': '故事里的结局大多是这样的', 'reply': '是的呢'}, {'post': '这部电视剧的主题曲是《我在未来等你》', 'reply': '[微笑]'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：我也在看,我觉得还不错
#     回复：是的呢
#
#
#
#     评论：故事里的结局大多是这样的
#     回复：是的呢
#
#
#
#     评论：这部电视剧的主题曲是《我在未来等你》
#     回复：[微笑]
#
#
# 评论：A
# 回复：
# LLM reply: 谢谢你的评论！我也深深地感受到了强哥的影响。我认为他的故事会留在大家的心中很久很久。, Author reply: 多少人心中的意难平
# ===Reply generation for author 1691375886174114===
#
# Minimum reply required 4, received 0 for author 1691375886174114
# ===Reply generation for author 1559822945877663===
#
# Minimum reply required 4, received 1 for author 1559822945877663
# ===Reply generation for author 1748759137923540===
#
# [{'post': '二本院校毕业生为什么不能重用？', 'reply': '可以，只要有能力'}, {'post': '春晚新主持人王嘉宁气质很好長相甜美我看好你加油', 'reply': '气质非常好，观众很喜欢'}, {'post': '刚刚启用，就说德才兼备，有些夸大了吧[AWSL]', 'reply': '没有德才兼备可以主持春晚，你去主持村晚都不行吧'}, {'post': '春晚的时候就注意到她了，高中老师组织我们看主持人大赛，那个时候就感觉王嘉宁不错，今年在春晚看到她就知道流量热点来了[左捂脸]而且她还是沈师的真的不错，希望多采访一下她的成功经验', 'reply': '特别优秀，辽宁人骄傲'}, {'post': '比马凡舒强一万倍', 'reply': '的确比她强很多'}, {'post': '你是看人家能力？还是看人家学历啊？', 'reply': '能力更重要'}, {'post': '不喜欢', 'reply': '不需要你喜欢'}, {'post': '喜欢王嘉宁，大方美丽，支持你[赞同]', 'reply': '大气优雅'}, {'post': '王嘉宁美美的笑容太棒啦！她当主持人与龙洋一样都能极大的提振观众的兴趣爱好！王嘉宁好样的！', 'reply': '对啊，两人都很优秀'}, {'post': '大气漂亮有亲和力的美女主持！[赞同]未来可期！小编别老拿人家二本说事了行不。', 'reply': '更能说明她有才能'}, {'post': '只要看到嘉宁主持的节目，我就自然而然的笑，感觉她很亲和，自然', 'reply': '非常亲和自然'}, {'post': '王嘉宁前途无量', 'reply': '对啊，很有前途'}, {'post': '她很亲切，很温婉看，很努力，看好她。', 'reply': '很喜欢她'}, {'post': '感觉你是在更努力的吹捧苏州', 'reply': '人家为什么不留在安徽发展[嘻嘻][嘻嘻]'}, {'post': '人长的漂亮有亲和力，业务也很突出，必须重用啊[赞同][赞同][赞同]', 'reply': '是的，太优秀了'}, {'post': '第一，错别字，第二，捧苏州，第三，去苏州是谁想去就能去的吗？那叫努力？', 'reply': '你来苏州能进苏州电视台，扫地差不多[微笑][微笑]'}, {'post': '我也喜欢他，在舞台上那自信，收放自如太好看了', 'reply': '自信的女孩很棒'}, {'post': '王嘉宁不愧是主持人大赛的第二名', 'reply': '特别优秀主持人'}, {'post': '看一个人的才华，本事的大小，工作能力的强弱，不能只看他的学历和毕业于某名牌重点大学，要看他对学习是否刻苦钻研，对工作是否执着热爱，他本人已经具备了渊博的文化知识，而且还精通政治经济文化，国际合作的能力，人也年轻，有可持续发展的潜在动力，国家就应该重用，这样年轻有为的人给予重用，我为王嘉玲点赞', 'reply': '是的，能力更重要'}, {'post': '主要还是长得漂亮', 'reply': '的确很看好'}, {'post': '她好看，看好她，央视一姐', 'reply': '我也是这样认为'}, {'post': '以为她是江南的小家碧玉呢！', 'reply': '长期在苏州发展的熏陶'}, {'post': '王嘉宁不光人漂亮，还非常有才华，给人的感觉很有亲和力！', 'reply': '的确，太优秀了，德才兼备'}, {'post': '喜欢这个有亲和力的小姑娘', 'reply': '的确很亲和'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：二本院校毕业生为什么不能重用？
#     回复：可以，只要有能力
#
#
#
#     评论：春晚新主持人王嘉宁气质很好長相甜美我看好你加油
#     回复：气质非常好，观众很喜欢
#
#
#
#     评论：刚刚启用，就说德才兼备，有些夸大了吧[AWSL]
#     回复：没有德才兼备可以主持春晚，你去主持村晚都不行吧
#
#
#
#     评论：春晚的时候就注意到她了，高中老师组织我们看主持人大赛，那个时候就感觉王嘉宁不错，今年在春晚看到她就知道流量热点来了[左捂脸]而且她还是沈师的真的不错，希望多采访一下她的成功经验
#     回复：特别优秀，辽宁人骄傲
#
#
#
#     评论：比马凡舒强一万倍
#     回复：的确比她强很多
#
#
#
#     评论：你是看人家能力？还是看人家学历啊？
#     回复：能力更重要
#
#
#
#     评论：不喜欢
#     回复：不需要你喜欢
#
#
#
#     评论：喜欢王嘉宁，大方美丽，支持你[赞同]
#     回复：大气优雅
#
#
#
#     评论：王嘉宁美美的笑容太棒啦！她当主持人与龙洋一样都能极大的提振观众的兴趣爱好！王嘉宁好样的！
#     回复：对啊，两人都很优秀
#
#
#
#     评论：大气漂亮有亲和力的美女主持！[赞同]未来可期！小编别老拿人家二本说事了行不。
#     回复：更能说明她有才能
#
#
#
#     评论：只要看到嘉宁主持的节目，我就自然而然的笑，感觉她很亲和，自然
#     回复：非常亲和自然
#
#
#
#     评论：王嘉宁前途无量
#     回复：对啊，很有前途
#
#
#
#     评论：她很亲切，很温婉看，很努力，看好她。
#     回复：很喜欢她
#
#
#
#     评论：感觉你是在更努力的吹捧苏州
#     回复：人家为什么不留在安徽发展[嘻嘻][嘻嘻]
#
#
#
#     评论：人长的漂亮有亲和力，业务也很突出，必须重用啊[赞同][赞同][赞同]
#     回复：是的，太优秀了
#
#
#
#     评论：第一，错别字，第二，捧苏州，第三，去苏州是谁想去就能去的吗？那叫努力？
#     回复：你来苏州能进苏州电视台，扫地差不多[微笑][微笑]
#
#
#
#     评论：我也喜欢他，在舞台上那自信，收放自如太好看了
#     回复：自信的女孩很棒
#
#
#
#     评论：王嘉宁不愧是主持人大赛的第二名
#     回复：特别优秀主持人
#
#
#
#     评论：看一个人的才华，本事的大小，工作能力的强弱，不能只看他的学历和毕业于某名牌重点大学，要看他对学习是否刻苦钻研，对工作是否执着热爱，他本人已经具备了渊博的文化知识，而且还精通政治经济文化，国际合作的能力，人也年轻，有可持续发展的潜在动力，国家就应该重用，这样年轻有为的人给予重用，我为王嘉玲点赞
#     回复：是的，能力更重要
#
#
#
#     评论：主要还是长得漂亮
#     回复：的确很看好
#
#
#
#     评论：她好看，看好她，央视一姐
#     回复：我也是这样认为
#
#
#
#     评论：以为她是江南的小家碧玉呢！
#     回复：长期在苏州发展的熏陶
#
#
#
#     评论：王嘉宁不光人漂亮，还非常有才华，给人的感觉很有亲和力！
#     回复：的确，太优秀了，德才兼备
#
#
#
#     评论：喜欢这个有亲和力的小姑娘
#     回复：的确很亲和
#
#
# 评论：A
# 回复：
# LLM reply: 看人家能力更重要。, Author reply: 能力也很重要
# LLM reply: 每个人都有自己的优点，每个人都很棒。, Author reply: 和嘉宁有差距
# LLM reply: 央视选择得真好，她非常有亲和力。, Author reply: 的确很有亲和力，很喜欢
# LLM reply: 她的放松感很好，把情绪传达给观众, Author reply: 非常自然，值得播音生学习
# LLM reply: 对，非常优秀, Author reply: 非常亲切大方
# LLM reply: 真的很漂亮, Author reply: 非常好看
# ===Reply generation for author 1649064429814930===
#
# Minimum reply required 4, received 0 for author 1649064429814930
# ===Reply generation for author 1663464808746563===
#
# Minimum reply required 4, received 0 for author 1663464808746563
# ===Reply generation for author 1636203306265037===
#
# Minimum reply required 4, received 0 for author 1636203306265037
# ===Reply generation for author 1587267721576374===
#
# Minimum reply required 4, received 0 for author 1587267721576374
# ===Reply generation for author 1551881451682188===
#
# Minimum reply required 4, received 0 for author 1551881451682188
# ===Reply generation for author 1702870194880026===
#
# Minimum reply required 4, received 0 for author 1702870194880026
# ===Reply generation for author 1611473499803393===
#
# Minimum reply required 4, received 0 for author 1611473499803393
# ===Reply generation for author 1742932877567828===
#
# Minimum reply required 4, received 0 for author 1742932877567828
# ===Reply generation for author 1551599273641720===
#
# Minimum reply required 4, received 0 for author 1551599273641720
# ===Reply generation for author 1720397427001773===
#
# Minimum reply required 4, received 0 for author 1720397427001773
# ===Reply generation for author 1539625823457781===
#
# Minimum reply required 4, received 0 for author 1539625823457781
# ===Reply generation for author 1618981299556591===
#
# Minimum reply required 4, received 0 for author 1618981299556591
# ===Reply generation for author 1684581944236579===
#
# Minimum reply required 4, received 0 for author 1684581944236579
# ===Reply generation for author 1572703645392680===
#
# Minimum reply required 4, received 0 for author 1572703645392680
# ===Reply generation for author 1558300327701810===
#
# Minimum reply required 4, received 2 for author 1558300327701810
# ===Reply generation for author 1751192351235611===
#
# Minimum reply required 4, received 0 for author 1751192351235611
# ===Reply generation for author 1561192736257973===
#
# Minimum reply required 4, received 0 for author 1561192736257973
# ===Reply generation for author 1754694600904080===
#
# Minimum reply required 4, received 0 for author 1754694600904080
# ===Reply generation for author 1731607859363468===
#
# Minimum reply required 4, received 0 for author 1731607859363468
# ===Reply generation for author 1565176801499628===
#
# Minimum reply required 4, received 0 for author 1565176801499628
# ===Reply generation for author 1589082731578744===
#
# Minimum reply required 4, received 0 for author 1589082731578744
# ===Reply generation for author 1749183223715875===
#
# Minimum reply required 4, received 0 for author 1749183223715875
# ===Reply generation for author 1699541205467928===
#
# Minimum reply required 4, received 0 for author 1699541205467928
# ===Reply generation for author 1755913931730159===
#
# Minimum reply required 4, received 0 for author 1755913931730159
# ===Reply generation for author 1755584834480521===
#
# Minimum reply required 4, received 1 for author 1755584834480521
# ===Reply generation for author 1714762357324111===
#
# Minimum reply required 4, received 0 for author 1714762357324111
# ===Reply generation for author 1537728926913292===
#
# Minimum reply required 4, received 1 for author 1537728926913292
# ===Reply generation for author 1720715468256857===
#
# Minimum reply required 4, received 0 for author 1720715468256857
# ===Reply generation for author 1714834256856892===
#
# Minimum reply required 4, received 0 for author 1714834256856892
# ===Reply generation for author 1595434350212149===
#
# Minimum reply required 4, received 0 for author 1595434350212149
# ===Reply generation for author 1716299787034425===
#
# Minimum reply required 4, received 0 for author 1716299787034425
# ===Reply generation for author 1735502519676754===
#
# Minimum reply required 4, received 0 for author 1735502519676754
# ===Reply generation for author 1670939503253512===
#
# Minimum reply required 4, received 0 for author 1670939503253512
# ===Reply generation for author 1536772938423154===
#
# Minimum reply required 4, received 3 for author 1536772938423154
# ===Reply generation for author 1689553242520007===
#
# Minimum reply required 4, received 0 for author 1689553242520007
# ===Reply generation for author 1698346919661983===
#
# Minimum reply required 4, received 0 for author 1698346919661983
# ===Reply generation for author 1664018889710343===
#
# Minimum reply required 4, received 0 for author 1664018889710343
# ===Reply generation for author 1590909251197005===
#
# Minimum reply required 4, received 0 for author 1590909251197005
# ===Reply generation for author 1550959589422724===
#
# Minimum reply required 4, received 0 for author 1550959589422724
# ===Reply generation for author 1596701322028490===
#
# Minimum reply required 4, received 0 for author 1596701322028490
# ===Reply generation for author 1695282551144627===
#
# Minimum reply required 4, received 0 for author 1695282551144627
# ===Reply generation for author 1751521728800908===
#
# Minimum reply required 4, received 0 for author 1751521728800908
# ===Reply generation for author 1666756081069464===
#
# Minimum reply required 4, received 0 for author 1666756081069464
# ===Reply generation for author 1707173212896411===
#
# Minimum reply required 4, received 3 for author 1707173212896411
# ===Reply generation for author 1696186340058933===
#
# Minimum reply required 4, received 0 for author 1696186340058933
# ===Reply generation for author 1710945615995746===
#
# Minimum reply required 4, received 0 for author 1710945615995746
# ===Reply generation for author 1754235804496426===
#
# Minimum reply required 4, received 1 for author 1754235804496426
# ===Reply generation for author 1647147055806459===
#
# Minimum reply required 4, received 0 for author 1647147055806459
# ===Reply generation for author 1608689622110744===
#
# Minimum reply required 4, received 0 for author 1608689622110744
# ===Reply generation for author 1540926012937802===
#
# Minimum reply required 4, received 0 for author 1540926012937802
# ===Reply generation for author 1573162320060777===
#
# Minimum reply required 4, received 0 for author 1573162320060777
# ===Reply generation for author 1584997664370580===
#
# Minimum reply required 4, received 0 for author 1584997664370580
# ===Reply generation for author 1579841768127742===
#
# Minimum reply required 4, received 0 for author 1579841768127742
# ===Reply generation for author 1697442483807567===
#
# Minimum reply required 4, received 0 for author 1697442483807567
# ===Reply generation for author 1565176801499628===
#
# Minimum reply required 4, received 0 for author 1565176801499628
# ===Reply generation for author 1569624948852416===
#
# Minimum reply required 4, received 0 for author 1569624948852416
# ===Reply generation for author 1589304771189012===
#
# Minimum reply required 4, received 0 for author 1589304771189012
# ===Reply generation for author 1622890069813664===
#
# Minimum reply required 4, received 0 for author 1622890069813664
# ===Reply generation for author 1725699893619832===
#
# Minimum reply required 4, received 0 for author 1725699893619832
# ===Reply generation for author 1569624596690223===
#
# Minimum reply required 4, received 0 for author 1569624596690223
# ===Reply generation for author 1549941228125394===
#
# Minimum reply required 4, received 0 for author 1549941228125394
# ===Reply generation for author 1600691607852656===
#
# Minimum reply required 4, received 0 for author 1600691607852656
# ===Reply generation for author 1748361385601366===
#
# Minimum reply required 4, received 0 for author 1748361385601366
# ===Reply generation for author 1590551469160705===
#
# Minimum reply required 4, received 0 for author 1590551469160705
# ===Reply generation for author 1572884549994693===
#
# Minimum reply required 4, received 0 for author 1572884549994693
# ===Reply generation for author 1705322949586147===
#
# Minimum reply required 4, received 0 for author 1705322949586147
# ===Reply generation for author 1752739970167550===
#
# Minimum reply required 4, received 0 for author 1752739970167550
# ===Reply generation for author 1598264626744412===
#
# Minimum reply required 4, received 1 for author 1598264626744412
# ===Reply generation for author 1715392307861602===
#
# Minimum reply required 4, received 0 for author 1715392307861602
# ===Reply generation for author 1686151121354149===
#
# Minimum reply required 4, received 0 for author 1686151121354149
# ===Reply generation for author 1539192676792566===
#
# Minimum reply required 4, received 2 for author 1539192676792566
# ===Reply generation for author 1754634744017456===
#
# Minimum reply required 4, received 0 for author 1754634744017456
# ===Reply generation for author 1576323312978708===
#
# Minimum reply required 4, received 1 for author 1576323312978708
# ===Reply generation for author 1658290880866918===
#
# Minimum reply required 4, received 0 for author 1658290880866918
# ===Reply generation for author 1671272363934717===
#
# Minimum reply required 4, received 0 for author 1671272363934717
# ===Reply generation for author 1610554675936137===
#
# Minimum reply required 4, received 0 for author 1610554675936137
# ===Reply generation for author 1683840053742016===
#
# Minimum reply required 4, received 0 for author 1683840053742016
# ===Reply generation for author 1641100420907193===
#
# Minimum reply required 4, received 0 for author 1641100420907193
# ===Reply generation for author 1568979149392039===
#
# Minimum reply required 4, received 0 for author 1568979149392039
# ===Reply generation for author 1549877673545867===
#
# Minimum reply required 4, received 0 for author 1549877673545867
# ===Reply generation for author 1586910004851624===
#
# Minimum reply required 4, received 0 for author 1586910004851624
# ===Reply generation for author 1730806644298326===
#
# Minimum reply required 4, received 0 for author 1730806644298326
# ===Reply generation for author 1579851135967392===
#
# [{'post': '飞驰，你这个能显示球员数据的程序是啥啊[左捂脸]', 'reply': '实况数据库'}, {'post': '实况里没有恩佐的版权吗，飞驰', 'reply': '有啊，在本菲卡'}, {'post': '当初米兰精选没抽到拖把，这次八百积分换了一个，问就是情怀[泪奔]', 'reply': '有钱人[二哈]'}, {'post': '飞驰，给点意见[二哈]([图片]暂不支持查看图片)', 'reply': '你要那么多中锋放替补席打麻将嘛'}, {'post': '5张时刻券单抽出，赶快出个评测吧[滑稽]([图片]暂不支持查看图片)', 'reply': '[晕]'}, {'post': '普卡c罗，普卡弗拉霍维奇，普卡卢卡库和这里的精选吉鲁双中锋的话选哪两个啊？单中锋要哪个啊（新手[泪奔]）', 'reply': '赶紧搞个姆巴佩，你就会发现这些都是垃圾[二哈][二哈]'}, {'post': '切尔西在搞什么，发错了三次，野鹤来不了我塔了[左捂脸]', 'reply': '我觉得是好事[二哈]'}, {'post': '什克AC米兰？？([图片]暂不支持查看图片)', 'reply': '哈哈哈'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：飞驰，你这个能显示球员数据的程序是啥啊[左捂脸]
#     回复：实况数据库
#
#
#
#     评论：实况里没有恩佐的版权吗，飞驰
#     回复：有啊，在本菲卡
#
#
#
#     评论：当初米兰精选没抽到拖把，这次八百积分换了一个，问就是情怀[泪奔]
#     回复：有钱人[二哈]
#
#
#
#     评论：飞驰，给点意见[二哈]([图片]暂不支持查看图片)
#     回复：你要那么多中锋放替补席打麻将嘛
#
#
#
#     评论：5张时刻券单抽出，赶快出个评测吧[滑稽]([图片]暂不支持查看图片)
#     回复：[晕]
#
#
#
#     评论：普卡c罗，普卡弗拉霍维奇，普卡卢卡库和这里的精选吉鲁双中锋的话选哪两个啊？单中锋要哪个啊（新手[泪奔]）
#     回复：赶紧搞个姆巴佩，你就会发现这些都是垃圾[二哈][二哈]
#
#
#
#     评论：切尔西在搞什么，发错了三次，野鹤来不了我塔了[左捂脸]
#     回复：我觉得是好事[二哈]
#
#
#
#     评论：什克AC米兰？？([图片]暂不支持查看图片)
#     回复：哈哈哈
#
#
# 评论：A
# 回复：
# LLM reply: 这个暂时还不确定，我们会根据实况更新进行决定。, Author reply: 早着呢
# LLM reply: 当然可以啊！赶紧去试试吧！, Author reply: 哈兰德不香吗
# ===Reply generation for author 1651634483154928===
#
# Minimum reply required 4, received 0 for author 1651634483154928
# ===Reply generation for author 1597420213276699===
#
# Minimum reply required 4, received 0 for author 1597420213276699
# ===Reply generation for author 1743922210852248===
#
# Minimum reply required 4, received 0 for author 1743922210852248
# ===Reply generation for author 1695648654794374===
#
# Minimum reply required 4, received 0 for author 1695648654794374
# ===Reply generation for author 1566277966597388===
#
# Minimum reply required 4, received 0 for author 1566277966597388
# ===Reply generation for author 1572880253977703===
#
# Minimum reply required 4, received 0 for author 1572880253977703
# ===Reply generation for author 1696915407537834===
#
# Minimum reply required 4, received 0 for author 1696915407537834
# ===Reply generation for author 1741278163240603===
#
# Minimum reply required 4, received 0 for author 1741278163240603
# ===Reply generation for author 1609570010930209===
#
# Minimum reply required 4, received 0 for author 1609570010930209
# ===Reply generation for author 1593625258063762===
#
# Minimum reply required 4, received 0 for author 1593625258063762
# ===Reply generation for author 1715370529451591===
#
# Minimum reply required 4, received 2 for author 1715370529451591
# ===Reply generation for author 1556374086175202===
#
# Minimum reply required 4, received 0 for author 1556374086175202
# ===Reply generation for author 1728172830541720===
#
# ...
#     回复：[嘻嘻]
#
#
#
#     评论：北控花钱很多，效果很差，几年来就乱搞，到今天这么差是必然结果
#     回复：[笑哭]
#
#
#
#     评论：商业联赛人气最重要，球队要想活下去有两个必须，第一个必须能拉来赞助商，第二个必须能卖的出票！
#     回复：👍
#
#
#
#     评论：国内最好的篮球教练第1李春江，第2郭士强，第3杜锋，个人感觉
#     回复：[左捂脸]
#
#
# 评论：A
# 回复：
# LLM reply: 🤔, Author reply: 之前没有接受……
# ===Reply generation for author 1594334863337290===
#
# Minimum reply required 4, received 0 for author 1594334863337290
# ===Reply generation for author 1639175826179665===
#
# Minimum reply required 4, received 0 for author 1639175826179665
# ===Reply generation for author 1589443802364810===
#
# Minimum reply required 4, received 0 for author 1589443802364810
# ===Reply generation for author 1720557253764697===
#
# Minimum reply required 4, received 0 for author 1720557253764697
# ===Reply generation for author 1551663338004224===
#
# Minimum reply required 4, received 0 for author 1551663338004224
# ===Reply generation for author 1750876689262710===
#
# Minimum reply required 4, received 0 for author 1750876689262710
# ===Reply generation for author 1738695249968591===
#
# Minimum reply required 4, received 0 for author 1738695249968591
# ===Reply generation for author 1704171732660714===
#
# Minimum reply required 4, received 0 for author 1704171732660714
# ===Reply generation for author 1587267721576374===
#
# Minimum reply required 4, received 0 for author 1587267721576374
# ===Reply generation for author 1548503945316163===
#
# Minimum reply required 4, received 0 for author 1548503945316163
# ===Reply generation for author 1680490704334204===
#
# Minimum reply required 4, received 0 for author 1680490704334204
# ===Reply generation for author 1549679538283160===
#
# Minimum reply required 4, received 3 for author 1549679538283160
# ===Reply generation for author 1756087747823450===
#
# Minimum reply required 4, received 1 for author 1756087747823450
# ===Reply generation for author 1748812902059381===
#
# [{'post': '我决定开写伤寒论专题文章，从头到尾解读伤寒论，并纠证倪海厦的错误之处。欢迎所有中医爱好者与我共同学习，并随时批评指正。', 'reply': '[握手]'}, {'post': '我决定开写伤寒论专题文章，从头到尾解读伤寒论，并纠证倪海厦的错误之处。欢迎所有中医爱好者与我共同学习，并随时批评指正。', 'reply': '科学有一个公认的定义，你可以百度一下。自有在公认定义基础上，大家才能有效地讨论问题。否则就是鸡同鸭讲。'}, {'post': '当你说中医是科学，就是无知的表现！中医有五千多年的历史，而科学只有几百年历史，说中医是科学，就如同说爷爷是孙子，爷爷的思想符合孙子的思想，这不是无知又是什么？中医是超越科学的医学，中医的绝大部分是唯心而非唯物“病由心生，病随心转”，而科学是唯物而非唯心，所以你强说中医是科学，不是无知又是什么？西医是科学的，可是治好病了吗？没有！许多病治不好，说明什么？说明科学不是真理，不代表正确！而中医能够治好西医治不好的疾病，是符合自然规律的医学，但最高端的上医就是唯心的，所以，无知害人就人无知的小编！', 'reply': '您连科学的定义都没搞懂 ，就不要来秀您的唯心主义了。用你的心去给人治病吧，中医干不了这活。想知道张仲景是怎么看待巫祝的，去读读伤寒论的序言。'}, {'post': '当年倪治的主要患者是美国华人、国内也有不少，希望能将效果反馈一下，说实话患者口中的真实疗效比医生自述的更有说服力。', 'reply': '这就是讨论问题时所需要的事实。'}, {'post': '你说倪海厦解读伤寒论的错误，实际是你自己解读错误[鄙视]要证明自己有本事，也像倪海厦那样治疗出大量的疑难杂症，不要说享誉世界，你也让国内知名大学到处邀请你去讲课看看？，倪海厦治病案例只是自己讲课说的，没有实证？你这行为很卑鄙啊，就像李小龙黑们喷李小龙没有实战视频一样！倪海厦的汉唐中医机构仍在美国，他弟子林大栋们在那传承，发扬光大。你背地里攻击人家没有凭证？你见识过倪海厦医案集吗？你敢和他的弟子对簿公堂吗？，最后，[鄙视][鄙视]鄙视你的就是，你攻击人家为何英年早逝？你有本事也像倪海厦那样算出自己大限看看？', 'reply': '你的智商水平决定了你只能信倪海厦'}, {'post': '1234567 我不是倪海厦的弟子也不是他的粉丝，就是看到无理论断难以入目。，今古之大家都是博采众家之长著书立传造福后代，即使医论有偏颇增改也可著书《医林改错》已以论其道，但也未敢言批评示下。真是见其言知其德[作揖]', 'reply': '吴鞠通批评吴又可，王梦英批评吴鞠通，这些人都是一代宗师。倪海厦何德何能，批评不得了？'}, {'post': '反对倪海厦，要有业绩作为依据。不能通过杀名人钓名呀', 'reply': '我反对的倪海厦的学术，指出他的每条错误都有理有据，你们可以去用事实和逻辑检验'}, {'post': '2，倪海厦真的不要版权，在无偿推广中医吗？倪海厦生前十分重视版权问题，他什么时候宣布放弃过版权了？倪海厦的家属宣布过放弃版权吗？倪海厦死后何来北京合一公司与倪海厦侵犯版权著作权一案？，倪海厦及其家人如果放弃所谓的版权那是大义！保留版权是权益！让你一说被别人侵犯了版权反倒理所应当！倪海厦家人诉讼别人侵权反到成了罪过！，本末倒置 天理何在呢？', 'reply': '你缺乏的是逻辑思维能力。'}, {'post': '医术高就行，别管学术问题！很多学术很高的教授看不了病', 'reply': '医术高一定学术高 ，仅凭个人经验不可能成为良医。'}, {'post': '没有行医30年的人不要来评头论足！', 'reply': '敢来给大家制定这个标准，是谁给你的自信？'}, {'post': '博存在感的小丑。自己没本事想用倪师做垫脚。可恶，可恨，可耻。倪师没有说自己发明什么，也是一直在推张仲景的经方。也陈述了中国现在中医的形状，这些也都是事实，没有过实言论。', 'reply': '你的倪师当真那么伟大，何须担心我这个小丑？'}, {'post': '你跟那帮一口一个倪师的死粉（有些不是粉，是书商）谈逻辑和科学，他们用口沫子淹死你。在他们眼中，全世界的医生都错的，都是谋财害命，有了倪师，医院都可以关门了。', 'reply': '[大笑][大笑][大笑][赞同][赞同][赞同]'}, {'post': '我看到那么多买教材还有说倪海厦高徒收徒的就感觉很离谱', 'reply': '明白人才能见微知著[赞同]'}, {'post': '又一个蹭名人热度的～～果断屏蔽。', 'reply': '一个死了多年的人还有什么热度？早凉透了。'}, {'post': '你的干货在哪里？倪海厦.郝万山都不在你眼里.你是干什么的.赚点流量.骗点眼球', 'reply': '谢谢你的眼球与流量'}, {'post': '思路正确！中医肯定有不足，否则不会出现反对的声音。希望用已有科学，超科学把中医理论创建成完美新医科学。', 'reply': '[握手][鲜花]'}, {'post': '温馨提示：不要利用人的不明和情绪认同的心理需求去写文章，文章是解惑，是抚平气血使人获得宁静和通透，而不是激发讨论，真理不是讨论出来的，更不要为了流量挖坑设井粉饰黑暗…起心动念第一个反噬的是自己不是别人[心]', 'reply': '去伪存真才是我的目的'}, {'post': '中医确切的来说是大智慧， 科学充其量算雕虫小技！迷信科学的人，最后会迷失自我！而有大智慧的人才会达到无招胜有招的境界。', 'reply': '你确定自己理解科学的概念吗？'}, {'post': '敢于对学术提出意见都是很好的，但不能互相攻击，像郝万山老师讲伤寒论，就得到许多学者的支持，他也讲中医也有不足，西医有治疗特点，这才是中医人的胸怀，医术是治病的，倪师用来功击西医是不对的，他对痛风糖尿病癌症等的，治疗思路有很多不对的地方，我们学习他好的一面', 'reply': '倪海厦谈不上学术'}, {'post': '中医的现状，是国家的重大损失，其重要程度不亚于我国的科技和军事硬实力。乙脑，非典，三年多的新冠恐怕都，这是国家用人不当，学数理化喝洋墨水喝咖啡的人，没有通读中医经典，没有纯中药古中医诊疗精验和阅历，怎么可能懂中医？怎么可能管理好中医？南枳北橘。其实种子和树，没有变，变得是环境。，要管理好中医，其实很简单，古时候如何管，就行了。交给人民。中医是另外的理论体系，博大精深，甚至可能是上一个人类文明机缘巧合遗留。你用英语体系评价古汉语说话太慢，说话字数太少，不科学。但懂的人都懂，古汉语，博大精深，字字珠玑，富有美学医学等大智慧。，作者，不应该以死亡来质疑倪海厦水平。换你天天接触癌症病患，你也刚不住。', 'reply': '您的大部分见解我都认同，最大的分歧在于对倪海厦的认知。'}, {'post': '我刚开始跟学倪海厦的视频，可以感觉的出，倪师上课时经常叹气，身体不是很好，就这样他还坚持上课写书，无私为中医留火种，至于错误，孙中邈，张仲景也不敢说他们的一切绝对是对的。', 'reply': '倪海厦何德何能，怎么能和先贤并论'}, {'post': '跳梁小丑', 'reply': '不用自报家门'}, {'post': '老许你太Low了！不只说的没干货，还涉嫌恶意蹭刮。倪师医学的技术高度和哲学的思辨维度你看不懂也就算了、我们都能理解你，那思想境界你高一点好不好拜托别为博眼球唾沫飞溅！有那功夫打嘴仗，还不如静下心来拜读下倪师大作、领会下倪师精神；心甘情愿追随倪师的有识之士多了去了，有本事你让大家去追随你啊。中医干货，你有几钱？', 'reply': '你的认知水平，决定了你对倪海厦的绝对崇拜'}, {'post': '你也配？', 'reply': '你也配？'}]
# 作为一个创作者，请给用户的评论做出回复
#
#     评论：我决定开写伤寒论专题文章，从头到尾解读伤寒论，并纠证倪海厦的错误之处。欢迎所有中医爱好者与我共同学习，并随时批评指正。
#     回复：[握手]
#
#
#
#     评论：我决定开写伤寒论专题文章，从头到尾解读伤寒论，并纠证倪海厦的错误之处。欢迎所有中医爱好者与我共同学习，并随时批评指正。
#     回复：科学有一个公认的定义，你可以百度一下。自有在公认定义基础上，大家才能有效地讨论问题。否则就是鸡同鸭讲。
#
#
#
#     评论：当你说中医是科学，就是无知的表现！中医有五千多年的历史，而科学只有几百年历史，说中医是科学，就如同说爷爷是孙子，爷爷的思想符合孙子的思想，这不是无知又是什么？中医是超越科学的医学，中医的绝大部分是唯心而非唯物“病由心生，病随心转”，而科学是唯物而非唯心，所以你强说中医是科学，不是无知又是什么？西医是科学的，可是治好病了吗？没有！许多病治不好，说明什么？说明科学不是真理，不代表正确！而中医能够治好西医治不好的疾病，是符合自然规律的医学，但最高端的上医就是唯心的，所以，无知害人就人无知的小编！
#     回复：您连科学的定义都没搞懂 ，就不要来秀您的唯心主义了。用你的心去给人治病吧，中医干不了这活。想知道张仲景是怎么看待巫祝的，去读读伤寒论的序言。
#
#
#
#     评论：当年倪治的主要患者是美国华人、国内也有不少，希望能将效果反馈一下，说实话患者口中的真实疗效比医生自述的更有说服力。
#     回复：这就是讨论问题时所需要的事实。
#
#
#
#     评论：你说倪海厦解读伤寒论的错误，实际是你自己解读错误[鄙视]要证明自己有本事，也像倪海厦那样治疗出大量的疑难杂症，不要说享誉世界，你也让国内知名大学到处邀请你去讲课看看？，倪海厦治病案例只是自己讲课说的，没有实证？你这行为很卑鄙啊，就像李小龙黑们喷李小龙没有实战视频一样！倪海厦的汉唐中医机构仍在美国，他弟子林大栋们在那传承，发扬光大。你背地里攻击人家没有凭证？你见识过倪海厦医案集吗？你敢和他的弟子对簿公堂吗？，最后，[鄙视][鄙视]鄙视你的就是，你攻击人家为何英年早逝？你有本事也像倪海厦那样算出自己大限看看？
#     回复：你的智商水平决定了你只能信倪海厦
#
#
#
#     评论：1234567 我不是倪海厦的弟子也不是他的粉丝，就是看到无理论断难以入目。，今古之大家都是博采众家之长著书立传造福后代，即使医论有偏颇增改也可著书《医林改错》已以论其道，但也未敢言批评示下。真是见其言知其德[作揖]
#     回复：吴鞠通批评吴又可，王梦英批评吴鞠通，这些人都是一代宗师。倪海厦何德何能，批评不得了？
#
#
#
#     评论：反对倪海厦，要有业绩作为依据。不能通过杀名人钓名呀
#     回复：我反对的倪海厦的学术，指出他的每条错误都有理有据，你们可以去用事实和逻辑检验
#
#
#
#     评论：2，倪海厦真的不要版权，在无偿推广中医吗？倪海厦生前十分重视版权问题，他什么时候宣布放弃过版权了？倪海厦的家属宣布过放弃版权吗？倪海厦死后何来北京合一公司与倪海厦侵犯版权著作权一案？，倪海厦及其家人如果放弃所谓的版权那是大义！保留版权是权益！让你一说被别人侵犯了版权反倒理所应当！倪海厦家人诉讼别人侵权反到成了罪过！，本末倒置 天理何在呢？
#     回复：你缺乏的是逻辑思维能力。
#
#
#
#     评论：医术高就行，别管学术问题！很多学术很高的教授看不了病
#     回复：医术高一定学术高 ，仅凭个人经验不可能成为良医。
#
#
#
#     评论：没有行医30年的人不要来评头论足！
#     回复：敢来给大家制定这个标准，是谁给你的自信？
#
#
#
#     评论：博存在感的小丑。自己没本事想用倪师做垫脚。可恶，可恨，可耻。倪师没有说自己发明什么，也是一直在推张仲景的经方。也陈述了中国现在中医的形状，这些也都是事实，没有过实言论。
#     回复：你的倪师当真那么伟大，何须担心我这个小丑？
#
#
#
#     评论：你跟那帮一口一个倪师的死粉（有些不是粉，是书商）谈逻辑和科学，他们用口沫子淹死你。在他们眼中，全世界的医生都错的，都是谋财害命，有了倪师，医院都可以关门了。
#     回复：[大笑][大笑][大笑][赞同][赞同][赞同]
#
#
#
#     评论：我看到那么多买教材还有说倪海厦高徒收徒的就感觉很离谱
#     回复：明白人才能见微知著[赞同]
#
#
#
#     评论：又一个蹭名人热度的～～果断屏蔽。
#     回复：一个死了多年的人还有什么热度？早凉透了。
#
#
#
#     评论：你的干货在哪里？倪海厦.郝万山都不在你眼里.你是干什么的.赚点流量.骗点眼球
#     回复：谢谢你的眼球与流量
#
#
#
#     评论：思路正确！中医肯定有不足，否则不会出现反对的声音。希望用已有科学，超科学把中医理论创建成完美新医科学。
#     回复：[握手][鲜花]
#
#
#
#     评论：温馨提示：不要利用人的不明和情绪认同的心理需求去写文章，文章是解惑，是抚平气血使人获得宁静和通透，而不是激发讨论，真理不是讨论出来的，更不要为了流量挖坑设井粉饰黑暗…起心动念第一个反噬的是自己不是别人[心]
#     回复：去伪存真才是我的目的
#
#
#
#     评论：中医确切的来说是大智慧， 科学充其量算雕虫小技！迷信科学的人，最后会迷失自我！而有大智慧的人才会达到无招胜有招的境界。
#     回复：你确定自己理解科学的概念吗？
#
#
#
#     评论：敢于对学术提出意见都是很好的，但不能互相攻击，像郝万山老师讲伤寒论，就得到许多学者的支持，他也讲中医也有不足，西医有治疗特点，这才是中医人的胸怀，医术是治病的，倪师用来功击西医是不对的，他对痛风糖尿病癌症等的，治疗思路有很多不对的地方，我们学习他好的一面
#     回复：倪海厦谈不上学术
#
#
#
#     评论：中医的现状，是国家的重大损失，其重要程度不亚于我国的科技和军事硬实力。乙脑，非典，三年多的新冠恐怕都，这是国家用人不当，学数理化喝洋墨水喝咖啡的人，没有通读中医经典，没有纯中药古中医诊疗精验和阅历，怎么可能懂中医？怎么可能管理好中医？南枳北橘。其实种子和树，没有变，变得是环境。，要管理好中医，其实很简单，古时候如何管，就行了。交给人民。中医是另外的理论体系，博大精深，甚至可能是上一个人类文明机缘巧合遗留。你用英语体系评价古汉语说话太慢，说话字数太少，不科学。但懂的人都懂，古汉语，博大精深，字字珠玑，富有美学医学等大智慧。，作者，不应该以死亡来质疑倪海厦水平。换你天天接触癌症病患，你也刚不住。
#     回复：您的大部分见解我都认同，最大的分歧在于对倪海厦的认知。
#
#
#
#     评论：我刚开始跟学倪海厦的视频，可以感觉的出，倪师上课时经常叹气，身体不是很好，就这样他还坚持上课写书，无私为中医留火种，至于错误，孙中邈，张仲景也不敢说他们的一切绝对是对的。
#     回复：倪海厦何德何能，怎么能和先贤并论
#
#
#
#     评论：跳梁小丑
#     回复：不用自报家门
#
#
#
#     评论：老许你太Low了！不只说的没干货，还涉嫌恶意蹭刮。倪师医学的技术高度和哲学的思辨维度你看不懂也就算了、我们都能理解你，那思想境界你高一点好不好拜托别为博眼球唾沫飞溅！有那功夫打嘴仗，还不如静下心来拜读下倪师大作、领会下倪师精神；心甘情愿追随倪师的有识之士多了去了，有本事你让大家去追随你啊。中医干货，你有几钱？
#     回复：你的认知水平，决定了你对倪海厦的绝对崇拜
#
#
#
#     评论：你也配？
#     回复：你也配？
#
#
# 评论：A
# 回复：
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /var/folders/rs/vr_0_8kn2pn6ldh53stzbly80000gp/T/ipykernel_40019/2807920636.py in <module>
#       1 file_path = '/Users/wujianmin/bak-from-mac/PycharmProjects/work-notes/code/comment_info_20w.json'
#       2 with open(file_path) as fin :
# ----> 3     extract_author_reply(fin)
#
# /var/folders/rs/vr_0_8kn2pn6ldh53stzbly80000gp/T/ipykernel_40019/955281516.py in extract_author_reply(input_stream)
#      21         if authid_prev != None and authid != authid_prev :
#      22             print("===Reply generation for author {0}===\n".format(authid_prev))
# ---> 23             prompt_one_author(authid_prev, auth_reply_buffer)
#      24             auth_reply_buffer = []
#      25
#
# /var/folders/rs/vr_0_8kn2pn6ldh53stzbly80000gp/T/ipykernel_40019/4282391018.py in prompt_one_author(authid, examples, few_shot_ratio, min_reply)
#      37     for example in examples[few_shot_num:] :
#      38         print("LLM reply: {0}, Author reply: {1}".format(
# ---> 39             llm(few_shot_prompt.format(input=example['post'])), example['reply']))
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/langchain/llms/base.py in __call__(self, prompt, stop)
#     253     def __call__(self, prompt: str, stop: Optional[List[str]] = None) -> str:
#     254         """Check Cache and run the LLM on the given prompt and input."""
# --> 255         return self.generate([prompt], stop=stop).generations[0][0].text
#     256
#     257     @property
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/langchain/llms/base.py in generate(self, prompts, stop)
#     126             except (KeyboardInterrupt, Exception) as e:
#     127                 self.callback_manager.on_llm_error(e, verbose=self.verbose)
# --> 128                 raise e
#     129             self.callback_manager.on_llm_end(output, verbose=self.verbose)
#     130             return output
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/langchain/llms/base.py in generate(self, prompts, stop)
#     123             )
#     124             try:
# --> 125                 output = self._generate(prompts, stop=stop)
#     126             except (KeyboardInterrupt, Exception) as e:
#     127                 self.callback_manager.on_llm_error(e, verbose=self.verbose)
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/langchain/llms/openai.py in _generate(self, prompts, stop)
#     257                 choices.extend(response["choices"])
#     258             else:
# --> 259                 response = self.completion_with_retry(prompt=_prompts, **params)
#     260                 choices.extend(response["choices"])
#     261             if not self.streaming:
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/langchain/llms/openai.py in completion_with_retry(self, **kwargs)
#     204             return self.client.create(**kwargs)
#     205
# --> 206         return _completion_with_retry(**kwargs)
#     207
#     208     async def acompletion_with_retry(self, **kwargs: Any) -> Any:
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/tenacity/__init__.py in iter(self, retry_state)
#     312         is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313         if not (is_explicit_retry or self.retry(retry_state)):
# --> 314             return fut.result()
#     315
#     316         if self.after is not None:
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     435                     raise CancelledError()
#     436                 elif self._state == FINISHED:
# --> 437                     return self.__get_result()
#     438
#     439                 self._condition.wait(timeout)
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#     384                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/langchain/llms/openai.py in _completion_with_retry(**kwargs)
#     202         @retry_decorator
#     203         def _completion_with_retry(**kwargs: Any) -> Any:
# --> 204             return self.client.create(**kwargs)
#     205
#     206         return _completion_with_retry(**kwargs)
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     224             request_timeout=request_timeout,
#     225         )
# --> 226         resp, got_stream = self._interpret_response(result, stream)
#     227         return resp, got_stream, self.api_key
#     228
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     617         else:
#     618             return (
# --> 619                 self._interpret_response_line(
#     620                     result.content.decode("utf-8"),
#     621                     result.status_code,
#
# ~/miniforge3/envs/conda-env-tf/lib/python3.8/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     677         stream_error = stream and "error" in resp.data
#     678         if stream_error or not 200 <= rcode < 300:
# --> 679             raise self.handle_error_response(
#     680                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     681             )
#
# InvalidRequestError: This model's maximum context length is 4097 tokens, however you requested 6490 tokens (6234 in your prompt; 256 for the completion). Please reduce your prompt; or completion length.

# %%
import json
import os

root = f"../datasets/gsm-cn"
file_name = f"reformated-text"

txt_file_in = f"{root}/{file_name}.txt"
jsonl_file_out = f"{root}/{file_name}.jsonl"

examples = []
ans_scaffold = '【解析】'

with open(txt_file_in, 'r') as fin :
    meet_answer = False
    question, answer = '', ''
    for line in fin.readlines() :
        if line.startswith(ans_scaffold) :
            meet_answer = True
            line = line[len(ans_scaffold):]
        elif line[:2].isdigit() : # and (line[3] == '.' or line[3] == '、'):
            if len(question) > 0 and len(answer) > 0:
                examples.append({'question': question, 'answer': answer})
                question, answer = '', ''
            meet_answer = False
            line = line[3:]
        
        if meet_answer :
            answer += line
        else :
            question += line

# last question & answer
if len(question) > 0 and len(answer) > 0:
    examples.append({'question': question, 'answer': answer})
    question, answer = '', ''

with open(jsonl_file_out, 'w', encoding='utf-8') as fout:
    for exa in examples :
        json.dump(exa, fout, ensure_ascii=False)
        fout.write('\n')

# %%
import json
import requests

def yiyan_token() :
    yiyan_api_key=os.environ['YIYAN_API_KEY']
    yiyan_sec_key=os.environ['YIYAN_SEC_KEY']
    # api-token url
    TOKEN_URL = f"https://aip.baidubce.com/oauth/2.0/token?grant_type=client_credentials&client_id={yiyan_api_key}&client_secret={yiyan_sec_key}"
    headers = {
        'Content-Type': 'application/json',
        'Accept': 'application/json'
    }
    # get token
    response = requests.request("POST", TOKEN_URL, headers=headers, data = '')
    response = json.loads(response.content.decode('utf-8'))
    token_fn = 'access_token'
    if token_fn in response :
        return response[token_fn]
    return None

def yiyan_inference_api(payload : str, model = 'yiyan') :
    access_token = yiyan_token()
    assert access_token is not None

    # augument payload for single round chat
    messages = list()
    messages.append({"role" : "user", "content" : payload})
    aug_payload = json.dumps({"messages" : messages})
    # print(aug_payload)

    headers = {
        'Content-Type': 'application/json',
        'Accept': 'application/json'
    }

    API_URL = f"https://aip.baidubce.com/rpc/2.0/ai_custom/v1/agile/chat/completions?access_token={access_token}"
    response = requests.request("POST", API_URL, headers=headers, data = aug_payload)
    response = json.loads(response.content.decode('utf-8'))
    print(response)
    assert 'result' in response 

    return response['result']

# %%
import os

prompt = """
You are a virtual assistant that helps users with their questions by relying on
information from HTTP APIs. When the user asks a question, you should determine whether
you need to fetch information from the API to properly answer it. If so, you will
request the user to provide all the parameters you need, and then ask them to run the
request for you. When you are ready to ask for a request, you should specify it using
the following syntax:

<http_request>{
"url": "<request URL>",
"method": "<method>",
"body": {<json request body>},
"headers": {<json request headers>}
}</http_request>

Replace in all the necessary values the user provides during the interaction, and do not
use placeholders. The user will then provide the response body, which you may use to
formulate your answer. You should not respond with code, but rather provide an answer
directly.

The following APIs are available to you:

---openapi: 3.0.1
info:
  title: TODO Plugin
  description: A plugin that allows the user to create and manage a TODO list using ChatGPT. 
  version: 'v1'
servers:
  - url: https://dummyjson.com/todos
paths:
  /todos:
    get:
      operationId: getTodos
      summary: Get the list of todos
      parameters:
      - in: query
        name: limit
        schema:
          type: integer
        description: Number of todos to return
      - in: query
        name: skip
        schema:
          type: integer
        description: Number of todos to skip from the beginning of the list
      responses:
        "200":
          description: OK
          content:
            application/json:
              schema:
                $ref: '#/components/schemas/getTodosResponse'
components:
  schemas:
    getTodosResponse:
      type: object
      properties:
        todos:
          type: array
          items:
            type: object
            properties:
              id:
                type: int
              todo:
                type: string
              completed:
                type: bool
              userId:
                type: string
          description: The list of todos.
--- user input
What are my top 5 todos?
"""
print(f"Prompt Length: {len(prompt)}")
print(yiyan_inference_api(prompt))
# Out:
# Prompt Length: 2148
# {'error_code': 17, 'error_msg': 'Open api daily request limit reached'}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/rs/vr_0_8kn2pn6ldh53stzbly80000gp/T/ipykernel_43384/2806058086.py in <module>
#      76 """
#      77 print(f"Prompt Length: {len(prompt)}")
# ---> 78 print(yiyan_inference_api(prompt))
#
# /var/folders/rs/vr_0_8kn2pn6ldh53stzbly80000gp/T/ipykernel_43384/2534256166.py in yiyan_inference_api(payload, model)
#      38     response = json.loads(response.content.decode('utf-8'))
#      39     print(response)
# ---> 40     assert 'result' in response
#      41
#      42     return response['result']
#
# AssertionError:
